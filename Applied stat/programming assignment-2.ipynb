# %%
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd

# %%
apple= yf.download("AAPL",start='2020-01-01',end='2021-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple['Returns']=apple["Adj Close"].pct_change(1).dropna()

# %%
apple['Returns']
# Out:
# Date
# 2020-01-02         NaN
# 2020-01-03   -0.009722
# 2020-01-06    0.007968
# 2020-01-07   -0.004703
# 2020-01-08    0.016086
#                 ...
# 2020-12-24    0.007712
# 2020-12-28    0.035766
# 2020-12-29   -0.013315
# 2020-12-30   -0.008527
# 2020-12-31   -0.007702
# Name: Returns, Length: 253, dtype: float64

# %%
plt.figure(dpi=300,figsize=(9,3))
apple['Returns'].plot(kind='hist',bins=50)
plt.title("Apple Stock percent Change in Daily price")
plt.show()

# %%
wickets=pd.read_html("https://www.espncricinfo.com/records/team/bowling-most-wickets-career/india-6/combined-test-odi-and-t20i-records-11")

# %%
wickets=wickets[0]

# %%
wickets=wickets['Wkts']

# %%
fig = plt.figure(figsize =(10, 7))
plt.boxplot(wickets)
plt.title("Wickets taken by all Indian Bowlers in International")
plt.show()
